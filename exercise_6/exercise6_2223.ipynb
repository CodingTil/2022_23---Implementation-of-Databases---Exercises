# %% [markdown]
# <table style="width:100%; float:center; background-color:#FFFFFF" align="left">
# <tr>
# <td style="text-align:left; background-color:#FFFFFF"></td>
# <td style="text-align:right; background-color:#FFFFFF"><div>
# <img src="data:image/png;base64,..." width="500">
#
# </div>
# </td></tr>
# </table>

# %% [markdown]
# Prof. Dr. Sandra Geisler <br>
# Soo-Yon Kim, Liam Tirpitz
#
# January 9, 2023
#
# <center>
#
# <h1> Implementation of Databases <br />(Winter Term 2022/2023)</h1>
#
# <h1> Exercise 6</h1>
#
# </center>

# %% [markdown]
# ---
# **Due until Monday, January 23 at 23:59.
# Please submit your solutions as a Jupyter notebook to Moodle.
# Please do _not_ submit handwritten solutions!
# Please submit your solutions in groups of three.**
# Solutions to this exercise will be presented on Friday, January 27.
#
# ---

# %% [markdown]
# ### Group members: [Til Mohr, 405959], [Simon Michau, 406133], [Marc Ludevid Wulf, 405401]
# #### Insert all group members by double-clicking on this cell.

# %% [markdown]
# ---

# %% [markdown]
# ## Exercise 6.1 (Serializability & Synchronization) (6 pts)

# %% [markdown]
# Consider the following two schedules:
# $s1 = w3(x)w3(z)r1(x)w2(y)r1(y)c1c3w2(x)w2(z)c2$
# $s2 = w3(x)w3(z)c3r1(x)r1(y)w2(y)c1w2(x)w2(z)c2$
# For each of the two schedules:
# 1\. Give the respective set of conflict relations.
# 2\. Draw the corresponding conflict graph and upload the image to Moodle.
# 3\. Determine whether the schedule is conflict serializable or not, and explain your decision.

# %% [markdown]
# ### [ Please replace this text with your answer. ]

# %% [markdown]
# ## Exercise 6.2 (Recoverability) (6 pts)

# %% [markdown]
# Consider again the two schedules from above:
# $s1 = w3(x)w3(z)r1(x)w2(y)r1(y)c1c3w2(x)w2(z)c2$
# $s2 = w3(x)w3(z)c3r1(x)r1(y)w2(y)c1w2(x)w2(z)c2$
# For each of the recoverability classes ST (Strict), ACA (Avoid Cascading Abort), RC (Recoverable), decide whether each of the schedules s1 and s2 are a member, and explain your decisions.

# %% [markdown]
# ### [ Please replace this text with your answer. ]

# %% [markdown]
# ## Exercise 6.3 (B+-Tree Locking) (13 pts)

# %% [markdown]
# <img src="data:image/png;base64,..." width="1200">

# %% [markdown]
# Given is the above B+-tree, and the following notation:
#
# - Read Node: `r(node)`
# - Write Node: `w(node)`
# - Read Lock Node: `rl(node)`
# - Write Lock Node: `wl(node)`
# - Read Unlock Node: `ru(node)`
# - Write Unlock Node: `wu(node)`
#
# Further,
# - `create(node)` can be used to indicate creation of a new node,
# - `delete(node)` can be used to delete a node
# - `redistribute(node1, node2)` to indicate redistribution of entries between siblings.
#
# *Note, that nodes changed this way still need to be written.*
#
# For all nodes in the B+ tree, the following invariants should hold where n is the maximum number of pointers that a node can store:
#
# For all internal nodes:
# $\left\lceil\frac{n}{2}\right\rceil\leq \text{# node pointers} \leq n$
#
# For all leaf nodes:
# $\left\lceil\frac{n-1}{2}\right\rceil\leq \text{# data pointers} \leq n - 1$

# %% [markdown]
# ## Task
# List the steps involved in executing each of the following operations in the given order according to the simple tree locking algorithm
# starting with the B+-tree above.
#
# <ol>
#     <li>Search key=23</li>
#     <li>Insert key=22</li>
#     <li>Delete key=35</li>
#     <li>Insert key=36</li>
#     <li>Delete key=4</li>
#
# </ol>
#
# Redraw the result B+-tree if it is updated and name the file, as well as the individual trees comprehensibly.
# Please combine all resulting trees in a single, additional pdf
# Be specific about the kind of lock obtained and answer each question independently of the others, always starting with the tree above.
#
# **Note:** We would like to unlock a node _as early as possible_ to maximize concurrency. We also would like to _maximize throughput_, i.e., releasing a higher-level node has priority over releasing a lower level node.
#
# List the actions in the order they occur, and add short explanations if necessary. For deletions, use redistribution, if possible and necessary. For insertions, always split if necessary.

# %% [markdown]
# ### [ Please replace this text with your answer. ]

# %% [markdown]
# ## Exercise 6.4 (Recovery) (5 pts)

# %% [markdown]
#  Consider the recovery scenario described in the following. There are three transactions T1, T2, T3 updating pages A, B, C. At the time of the crash, the log, the Transaction Table, and the Dirty Page Table contain following entries:

# %% [markdown]
# <img src="data:image/png;base64,..." />

# %% [markdown]
# 1. What is done during _Analysis_ after the restart? Be precise about the points at which analysis begins and ends and describe the contents of any tables constructed in this phase.

# %% [markdown]
# ### [ Please replace this text with your answer. ]

# %% [markdown]
# 2. What is done during _Redo_? Be precise about the modifications to any tables due to processing of log records.

# %% [markdown]
# ### [ Please replace this text with your answer. ]

# %% [markdown]
# 3. What is done during _Undo_? Be precise about the modifications to the log and any tables due to processing of log records.

# %% [markdown]
# ### [ Please replace this text with your answer. ]

# %% [markdown]
# 2. What is done during _Redo_? Be precise about the modifications to any tables due to processing of log records.

# %% [markdown]
# ### [ Please replace this text with your answer. ]

# %% [markdown]
# 3. What is done during _Undo_? Be precise about the modifications to the log and any tables due to processing of log records.

# %% [markdown]
# ### [ Please replace this text with your answer. ]
